# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

plt.style.use("seaborn-v0_8")

# %%
#Load Your Dataset

df = pd.read_csv("Job_Market_India_with_skills.csv")

# %%
df.head()
# Out:
#   Record_Date         Company_Name            Job_Role Experience_Level  \
# 0  11/22/2015  State Bank of India     Product Manager        0-1 years
# 1  11/22/2015   Hindustan Unilever  Frontend Developer        0-1 years
# 2  11/22/2015     Bharat Petroleum   Software Engineer        5-8 years
# 3  11/22/2015            HDFC Bank      UI/UX Designer        5-8 years
# 4  11/22/2015        Maruti Suzuki        Data Analyst        1-3 years
#
#         City  Salary_INR  Demand_Index  Remote_Option_Flag  Salary_Trend_Pct
# 0      Noida     1615767            71                   0              8.72
# 1  Hyderabad      790163            81                   0              5.26
# 2  Bangalore     1104756            94                   0              0.08
# 3     Mumbai      905086            94                   1              8.22
# 4  Bangalore      578687            35                   0             11.54

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Record_Date         30000 non-null  object
#  1   Company_Name        30000 non-null  object
#  2   Job_Role            30000 non-null  object
#  3   Experience_Level    30000 non-null  object
#  4   City                30000 non-null  object
#  5   Salary_INR          30000 non-null  int64
#  6   Demand_Index        30000 non-null  int64
#  7   Remote_Option_Flag  30000 non-null  int64
#  8   Salary_Trend_Pct    30000 non-null  float64
#  9   Skills_Required     30000 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 2.3+ MB

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Record_Date           0
# Company_Name          0
# Job_Role              0
# Experience_Level      0
# City                  0
# Salary_INR            0
# Demand_Index          0
# Remote_Option_Flag    0
# Salary_Trend_Pct      0
# Skills_Required       0
# dtype: int64

# %%
df.dropna(subset=['Job_Role', 'Company_Name', 'Skills_Required'], inplace=True)

# %%
df['Record_Date'] = pd.to_datetime(df['Record_Date'])
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Record_Date         30000 non-null  datetime64[ns]
#  1   Company_Name        30000 non-null  object
#  2   Job_Role            30000 non-null  object
#  3   Experience_Level    30000 non-null  object
#  4   City                30000 non-null  object
#  5   Salary_INR          30000 non-null  int64
#  6   Demand_Index        30000 non-null  int64
#  7   Remote_Option_Flag  30000 non-null  int64
#  8   Salary_Trend_Pct    30000 non-null  float64
#  9   Skills_Required     30000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 2.3+ MB
# None

# %%
df.to_csv("cleaned_job_market.csv", index=False)
print("Cleaned data saved to 'cleaned_job_market.csv'")
# Out:
# Cleaned data saved to 'cleaned_job_market.csv'
